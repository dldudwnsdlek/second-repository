# %% [markdown]
# # Boston

# %%
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt

# %%
# keras.datasets 안에 boston_housing 데이터셋을 로드합니다.
from keras.datasets import boston_housing

(train_data, train_labels), (test_data, test_labels) = boston_housing.load_data()

# 데이터셋의 크기를 확인합니다.
print(len(train_data))
print(len(test_data))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/boston_housing.npz
# 57026/57026 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# 404
# 102

# %%
# 문제 1-1: 데이터셋의 전처리를 위해 표준화 작업을 수행합니다.
# 먼저 입력 데이터의 각 특성의 평균을 뺍니다.
mean = train_data.mean(axis=0)
train_data -= mean

# 평균을 뺀 입력 데이터에서 표준편차를 나눕니다.
# 데이터 특성의 중앙이 0에 가깝게 만들고, 표준편차가 1이 되게 만듭니다.
std = train_data.std(axis=0)
train_data /= std

# 테스트 데이터셋도 마찬가지로 평균을 빼고, 표준편차로 나눕니다.
test_data -= mean
test_data /= std

# %%
# 문제 1-2: 주택 가격 예측을 위한 딥러닝 모델 구성 및 컴파일합니다.
# input_shape은 (train_data.shape[1], )으로 구성합니다.
# 회귀(예측)을 위한 모델이므로 loss를 mse, metrics를 mae로 사용합니다.
# 모델 구성
model = models.Sequential()
model.add(layers.Dense(64, activation='relu', input_shape=(train_data.shape[1],)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(1))  # 출력층: 예측 값이 하나인 회귀 문제

# 모델 컴파일
model.compile(optimizer='adam', 
              loss='mse',  # 평균 제곱 오차
              metrics=['mae'])  # 평균 절대 오차
# Out:
# c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# 문제 1-3: 예측을 위한 딥러닝 모델을 학습합니다.
# 훈련/검증 데이터 분리
x_val = train_data[:100]  # 검증용 데이터 (100개)
partial_x_train = train_data[100:]  # 훈련 데이터 (나머지)

y_val = train_labels[:100]  # 검증 레이블
partial_y_train = train_labels[100:]  # 훈련 레이블

# 모델 학습
history = model.fit(
    partial_x_train,
    partial_y_train,
    epochs=100,  # 학습 반복 횟수
    batch_size=10,  # 배치 크기
    validation_data=(x_val, y_val),  # 검증 데이터
    verbose=1  # 학습 진행 상태 표시
)
# Out:
# Epoch 1/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 568.5884 - mae: 22.1910 - val_loss: 459.4257 - val_mae: 19.2988
# Epoch 2/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 463.4020 - mae: 19.3364 - val_loss: 261.8826 - val_mae: 13.9110
# Epoch 3/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 231.7993 - mae: 12.7274 - val_loss: 78.7054 - val_mae: 6.6852
# Epoch 4/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 89.2359 - mae: 7.3584 - val_loss: 43.2699 - val_mae: 4.7129
# Epoch 5/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 40.2249 - mae: 4.9550 - val_loss: 28.2486 - val_mae: 3.5905
# Epoch 6/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 23.6686 - mae: 3.8357 - val_loss: 23.1204 - val_mae: 3.1775
# Epoch 7/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 22.3451 - mae: 3.5574 - val_loss: 20.4912 - val_mae: 2.9949
# Epoch 8/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 16.4252 - mae: 3.1356 - val_loss: 18.7937 - val_mae: 2.8847
# Epoch 9/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 16.1692 - mae: 2.9608 - val_loss: 17.3823 - val_mae: 2.7729
# Epoch 10/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 16.2424 - mae: 2.9685 - val_loss: 16.1756 - val_mae: 2.6416
# Epoch 11/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 14.9421 - mae: 2.7635 - val_loss: 15.2381 - val_mae: 2.6125
# Epoch 12/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 18.7306 - mae: 2.9234 - val_loss: 14.7955 - val_mae: 2.5769
# Epoch 13/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 14.3727 - mae: 2.5742 - val_loss: 13.4132 - val_mae: 2.5006
# Epoch 14/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 15.7408 - mae: 2.6568 - val_loss: 12.8710 - val_mae: 2.4766
# Epoch 15/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 14.9119 - mae: 2.5909 - val_loss: 12.2298 - val_mae: 2.4086
# Epoch 16/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 13.2426 - mae: 2.6444 - val_loss: 11.5919 - val_mae: 2.3847
# Epoch 17/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 12.7382 - mae: 2.5899 - val_loss: 11.4484 - val_mae: 2.4793
# Epoch 18/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 13.5092 - mae: 2.5441 - val_loss: 10.9102 - val_mae: 2.3407
# Epoch 19/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 9.5978 - mae: 2.3663 - val_loss: 10.4389 - val_mae: 2.3072
# Epoch 20/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 14.5146 - mae: 2.6315 - val_loss: 10.6776 - val_mae: 2.3188
# Epoch 21/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 15.3554 - mae: 2.6109 - val_loss: 9.7803 - val_mae: 2.2280
# Epoch 22/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 11.1871 - mae: 2.3663 - val_loss: 9.4773 - val_mae: 2.2067
# Epoch 23/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 11.0649 - mae: 2.3018 - val_loss: 9.2238 - val_mae: 2.1381
# Epoch 24/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 10.3608 - mae: 2.4232 - val_loss: 9.4805 - val_mae: 2.2118
# Epoch 25/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 11.2769 - mae: 2.4260 - val_loss: 8.9465 - val_mae: 2.1572
# Epoch 26/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 10.9118 - mae: 2.0858 - val_loss: 8.8818 - val_mae: 2.0791
# Epoch 27/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.7771 - mae: 2.3044 - val_loss: 8.6059 - val_mae: 2.0533
# Epoch 28/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 10.9748 - mae: 2.3399 - val_loss: 8.8136 - val_mae: 2.1636
# Epoch 29/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 10.4445 - mae: 2.4310 - val_loss: 8.3012 - val_mae: 1.9978
# Epoch 30/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 11.5961 - mae: 2.2578 - val_loss: 8.4920 - val_mae: 2.0343
# Epoch 31/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.8862 - mae: 1.9458 - val_loss: 8.2573 - val_mae: 2.0614
# Epoch 32/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 10.0224 - mae: 2.3558 - val_loss: 8.2432 - val_mae: 2.0246
# Epoch 33/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.3454 - mae: 2.2270 - val_loss: 8.1238 - val_mae: 2.0836
# Epoch 34/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.1580 - mae: 2.1973 - val_loss: 8.0347 - val_mae: 2.0033
# Epoch 35/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.8666 - mae: 2.2831 - val_loss: 8.4415 - val_mae: 2.1268
# Epoch 36/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.8652 - mae: 2.1977 - val_loss: 7.6097 - val_mae: 1.9425
# Epoch 37/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.8314 - mae: 2.1172 - val_loss: 8.0538 - val_mae: 2.0484
# Epoch 38/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.6115 - mae: 1.9753 - val_loss: 7.9615 - val_mae: 1.9918
# Epoch 39/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.2330 - mae: 2.2451 - val_loss: 7.6492 - val_mae: 2.0059
# Epoch 40/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.0888 - mae: 1.9983 - val_loss: 7.6958 - val_mae: 1.8921
# Epoch 41/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.5231 - mae: 2.0940 - val_loss: 7.4264 - val_mae: 1.9559
# Epoch 42/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.3870 - mae: 2.2436 - val_loss: 7.4643 - val_mae: 1.9253
# Epoch 43/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.3456 - mae: 2.0476 - val_loss: 7.4967 - val_mae: 1.8913
# Epoch 44/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.8538 - mae: 2.1942 - val_loss: 7.4341 - val_mae: 1.9815
# Epoch 45/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.3109 - mae: 2.0944 - val_loss: 7.6821 - val_mae: 1.8894
# Epoch 46/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.3058 - mae: 2.0400 - val_loss: 7.5847 - val_mae: 2.0429
# Epoch 47/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.9349 - mae: 1.9641 - val_loss: 7.7594 - val_mae: 1.9160
# Epoch 48/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.0332 - mae: 1.9134 - val_loss: 7.6780 - val_mae: 2.0619
# Epoch 49/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.3070 - mae: 2.1443 - val_loss: 7.4314 - val_mae: 2.0027
# Epoch 50/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.6625 - mae: 2.0187 - val_loss: 7.1643 - val_mae: 1.9034
# Epoch 51/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.6370 - mae: 1.8565 - val_loss: 7.2103 - val_mae: 1.9459
# Epoch 52/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.6535 - mae: 2.0082 - val_loss: 7.3659 - val_mae: 1.9098
# Epoch 53/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.6312 - mae: 1.8808 - val_loss: 7.4600 - val_mae: 1.9638
# Epoch 54/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.7972 - mae: 1.9583 - val_loss: 7.2574 - val_mae: 1.8930
# Epoch 55/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.5338 - mae: 1.9596 - val_loss: 7.7812 - val_mae: 2.1017
# Epoch 56/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.9210 - mae: 1.8878 - val_loss: 7.2273 - val_mae: 1.8983
# Epoch 57/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.9676 - mae: 1.9734 - val_loss: 7.1650 - val_mae: 1.9214
# Epoch 58/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.8275 - mae: 2.0642 - val_loss: 7.1622 - val_mae: 1.9856
# Epoch 59/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.9861 - mae: 1.9861 - val_loss: 6.8941 - val_mae: 1.8599
# Epoch 60/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.6136 - mae: 2.0959 - val_loss: 6.8851 - val_mae: 1.8692
# Epoch 61/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.0916 - mae: 2.1015 - val_loss: 6.8410 - val_mae: 1.9128
# Epoch 62/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.3711 - mae: 1.9515 - val_loss: 6.8983 - val_mae: 1.8884
# Epoch 63/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.2533 - mae: 1.8103 - val_loss: 6.8299 - val_mae: 1.8846
# Epoch 64/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.1692 - mae: 1.8375 - val_loss: 7.0541 - val_mae: 1.9639
# Epoch 65/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.1098 - mae: 1.8611 - val_loss: 6.9511 - val_mae: 1.8931
# Epoch 66/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.8372 - mae: 1.8367 - val_loss: 6.7950 - val_mae: 1.8867
# Epoch 67/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.6858 - mae: 1.8151 - val_loss: 6.9029 - val_mae: 1.8862
# Epoch 68/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.9863 - mae: 1.7624 - val_loss: 6.8555 - val_mae: 1.9724
# Epoch 69/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.2045 - mae: 1.7466 - val_loss: 7.4099 - val_mae: 2.0481
# Epoch 70/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.6400 - mae: 1.7699 - val_loss: 7.5466 - val_mae: 2.1710
# Epoch 71/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.7213 - mae: 1.9196 - val_loss: 6.8444 - val_mae: 1.8972
# Epoch 72/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.2005 - mae: 1.6687 - val_loss: 7.3763 - val_mae: 2.1311
# Epoch 73/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.3454 - mae: 2.0263 - val_loss: 6.9552 - val_mae: 1.9155
# Epoch 74/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.6599 - mae: 1.8022 - val_loss: 6.7530 - val_mae: 1.8729
# Epoch 75/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.8342 - mae: 1.7020 - val_loss: 6.6888 - val_mae: 1.8841
# Epoch 76/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.0526 - mae: 1.9147 - val_loss: 6.9145 - val_mae: 1.9236
# Epoch 77/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.8974 - mae: 1.7936 - val_loss: 6.9856 - val_mae: 1.9628
# Epoch 78/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.7245 - mae: 1.7363 - val_loss: 6.8898 - val_mae: 1.9706
# Epoch 79/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.7977 - mae: 1.8805 - val_loss: 6.7151 - val_mae: 2.0300
# Epoch 80/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.7390 - mae: 1.7346 - val_loss: 6.8759 - val_mae: 1.9990
# Epoch 81/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.0764 - mae: 1.7118 - val_loss: 7.1744 - val_mae: 1.9169
# Epoch 82/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.8603 - mae: 1.7558 - val_loss: 6.6875 - val_mae: 1.9394
# Epoch 83/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.9165 - mae: 1.7923 - val_loss: 6.8127 - val_mae: 1.9843
# Epoch 84/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.7907 - mae: 1.8023 - val_loss: 6.8221 - val_mae: 1.9692
# Epoch 85/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.0241 - mae: 1.8296 - val_loss: 6.9220 - val_mae: 1.9836
# Epoch 86/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.4673 - mae: 1.7866 - val_loss: 6.9132 - val_mae: 1.9753
# Epoch 87/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.0401 - mae: 1.7005 - val_loss: 6.7148 - val_mae: 1.9174
# Epoch 88/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.1250 - mae: 1.7388 - val_loss: 6.9240 - val_mae: 1.9845
# Epoch 89/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.7193 - mae: 1.6097 - val_loss: 6.8654 - val_mae: 1.9688
# Epoch 90/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.8145 - mae: 1.8232 - val_loss: 7.0894 - val_mae: 2.0144
# Epoch 91/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.6514 - mae: 1.7296 - val_loss: 6.7447 - val_mae: 1.9284
# Epoch 92/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.0455 - mae: 1.7031 - val_loss: 6.7996 - val_mae: 2.0295
# Epoch 93/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 4.9054 - mae: 1.5585 - val_loss: 6.6796 - val_mae: 1.9394
# Epoch 94/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.1242 - mae: 1.6249 - val_loss: 6.9059 - val_mae: 2.0201
# Epoch 95/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.4036 - mae: 1.6006 - val_loss: 6.9703 - val_mae: 1.9696
# Epoch 96/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.3779 - mae: 1.6696 - val_loss: 6.5745 - val_mae: 1.9377
# Epoch 97/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.2515 - mae: 1.6754 - val_loss: 6.7475 - val_mae: 1.9697
# Epoch 98/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.8509 - mae: 1.6597 - val_loss: 6.8302 - val_mae: 1.9215
# Epoch 99/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.0844 - mae: 1.7575 - val_loss: 6.6292 - val_mae: 1.9245
# Epoch 100/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.4952 - mae: 1.6064 - val_loss: 7.2237 - val_mae: 2.1582

# %%
# 모델 학습 히스토리에서 loss, val_loss, mae, val_mae를 차트로 보여줍니다.


history_dict = history.history

loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)
fig = plt.figure(figsize=(12, 5))

ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, loss, 'b-', label='train_loss')
ax1.plot(epochs, val_loss, 'r-', label='val_loss')
ax1.set_title('Train and Validation Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.grid()
ax1.legend()

mae = history_dict['mae']
val_mae = history_dict['val_mae']

ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, mae, 'b-', label='train_mae')
ax2.plot(epochs, val_mae, 'r-', label='val_mae')
ax2.set_title('Train and Validation MAE')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.grid()
ax2.legend()

plt.show()

# %%
# 문제 1-4: 테스트 데이터셋을 이용해 모델을 평가합니다.
# 테스트 데이터셋으로 모델 평가
test_loss, test_mae = model.evaluate(test_data, test_labels, verbose=1)

print(f"Test Loss: {test_loss:.4f}")
print(f"Test MAE: {test_mae:.4f}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 14.9113 - mae: 2.7505
# Test Loss: 20.1511
# Test MAE: 2.8939

# %% [markdown]
# # Reuters

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from tensorflow.keras import models, layers
from tensorflow.keras import callbacks
from tensorflow.keras import utils
from keras.datasets import reuters

# %%
# 문제 2-1: reuters 데이터셋을 로드하고, 훈련 데이터셋에서 25%를 검증 데이터셋으로 분리합니다.
# 문제 2-1: reuters 데이터셋을 로드하고, 훈련 데이터셋에서 25%를 검증 데이터셋으로 분리합니다.
(train_data, train_labels), (test_data, test_labels) = reuters.load_data(num_words=10000)

# 훈련 데이터셋을 훈련용 데이터와 검증용 데이터로 나눕니다.
train_data, val_data, train_labels, val_labels = train_test_split(
    train_data, train_labels, test_size=0.25, random_state=42
)

# 훈련, 검증, 테스트 데이터와 레이블 종류가 몇 개인지 출력합니다.
print(len(train_data))
print(len(val_data))
print(len(test_data))
print(len(set(train_labels)))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2110848/2110848 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# 6736
# 2246
# 2246
# 46

# %%
# 문제 2-2: 텍스트 데이터의 전처리를 위해서 각 데이터셋마다 원-핫 인코딩을 수행합니다.
def one_hot_encoding(data, dim=10000):
    results = np.zeros((len(data), dim))
    for i, sequence in enumerate(data):
        results[i, sequence] = 1.0
    return results

x_train = one_hot_encoding(train_data)
x_val = one_hot_encoding(val_data)
x_test = one_hot_encoding(test_data)

# 레이블 데이터들은 범주형 형태로 to_categorical() 함수를 사용해 변환합니다.
y_train = utils.to_categorical(train_labels)
y_val = utils.to_categorical(val_labels)
y_test = utils.to_categorical(test_labels)

# %%
# 문제 2-3: 빠른 학습과 과대적합을 방지하기 위해 BatchNormalization과 Dropout을 적용한 딥러닝 모델을 구성합니다.
model = models.Sequential()
model.add(layers.Dense(512, activation='relu', input_shape=(10000,)))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(46, activation='softmax'))
# Out:
# c:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
              
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 512)            │     5,120,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 46)             │        11,822 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,266,734 (20.09 MB)
#  Trainable params: 5,265,198 (20.09 MB)
#  Non-trainable params: 1,536 (6.00 KB)

# %%
# 문제 2-4: ModelCheckpoint와 EarlyStopping 콜백 함수를 적용하여 모델 학습을 진행합니다.
checkpoint = callbacks.ModelCheckpoint(
    'best_model.keras', save_best_only=True, monitor='val_loss', mode='min'
)
early_stopping = callbacks.EarlyStopping(
    monitor='val_loss', patience=5, restore_best_weights=True
)

history = model.fit(
    x_train, y_train,
    epochs=50,
    batch_size=512,
    validation_data=(x_val, y_val),
    callbacks=[checkpoint, early_stopping]
)
# Out:
# Epoch 1/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 9s 306ms/step - accuracy: 0.3055 - loss: 3.6199 - val_accuracy: 0.6581 - val_loss: 3.1942
# Epoch 2/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 248ms/step - accuracy: 0.7254 - loss: 1.3465 - val_accuracy: 0.7395 - val_loss: 2.8626
# Epoch 3/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 176ms/step - accuracy: 0.8166 - loss: 0.8958 - val_accuracy: 0.7649 - val_loss: 2.6937
# Epoch 4/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 209ms/step - accuracy: 0.8660 - loss: 0.6510 - val_accuracy: 0.7729 - val_loss: 2.5784
# Epoch 5/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 192ms/step - accuracy: 0.9011 - loss: 0.4600 - val_accuracy: 0.7760 - val_loss: 2.4149
# Epoch 6/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 226ms/step - accuracy: 0.9157 - loss: 0.3687 - val_accuracy: 0.7729 - val_loss: 2.2490
# Epoch 7/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 5s 174ms/step - accuracy: 0.9398 - loss: 0.2826 - val_accuracy: 0.7654 - val_loss: 2.0949
# Epoch 8/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 197ms/step - accuracy: 0.9415 - loss: 0.2594 - val_accuracy: 0.7609 - val_loss: 1.9523
# Epoch 9/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 171ms/step - accuracy: 0.9548 - loss: 0.2091 - val_accuracy: 0.7765 - val_loss: 1.7708
# Epoch 10/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 196ms/step - accuracy: 0.9587 - loss: 0.1759 - val_accuracy: 0.7823 - val_loss: 1.6330
# Epoch 11/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 191ms/step - accuracy: 0.9612 - loss: 0.1717 - val_accuracy: 0.7823 - val_loss: 1.5273
# Epoch 12/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 172ms/step - accuracy: 0.9609 - loss: 0.1625 - val_accuracy: 0.7912 - val_loss: 1.3923
# Epoch 13/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 219ms/step - accuracy: 0.9596 - loss: 0.1734 - val_accuracy: 0.7907 - val_loss: 1.2735
# Epoch 14/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 200ms/step - accuracy: 0.9617 - loss: 0.1525 - val_accuracy: 0.7934 - val_loss: 1.2062
# Epoch 15/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 241ms/step - accuracy: 0.9665 - loss: 0.1393 - val_accuracy: 0.8001 - val_loss: 1.1117
# Epoch 16/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 199ms/step - accuracy: 0.9682 - loss: 0.1330 - val_accuracy: 0.8045 - val_loss: 1.0528
# Epoch 17/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 321ms/step - accuracy: 0.9632 - loss: 0.1331 - val_accuracy: 0.8028 - val_loss: 1.0060
# Epoch 18/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 264ms/step - accuracy: 0.9671 - loss: 0.1340 - val_accuracy: 0.8032 - val_loss: 0.9817
# Epoch 19/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 295ms/step - accuracy: 0.9681 - loss: 0.1350 - val_accuracy: 0.8094 - val_loss: 0.9520
# Epoch 20/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 270ms/step - accuracy: 0.9705 - loss: 0.1186 - val_accuracy: 0.8099 - val_loss: 0.9338
# Epoch 21/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 232ms/step - accuracy: 0.9693 - loss: 0.1235 - val_accuracy: 0.8134 - val_loss: 0.9201
# Epoch 22/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 205ms/step - accuracy: 0.9682 - loss: 0.1228 - val_accuracy: 0.8188 - val_loss: 0.9183
# Epoch 23/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 322ms/step - accuracy: 0.9721 - loss: 0.1081 - val_accuracy: 0.8210 - val_loss: 0.9177
# Epoch 24/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 247ms/step - accuracy: 0.9723 - loss: 0.1003 - val_accuracy: 0.8228 - val_loss: 0.9130
# Epoch 25/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 245ms/step - accuracy: 0.9698 - loss: 0.1162 - val_accuracy: 0.8232 - val_loss: 0.9346
# Epoch 26/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 160ms/step - accuracy: 0.9687 - loss: 0.1193 - val_accuracy: 0.8188 - val_loss: 0.9524
# Epoch 27/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 193ms/step - accuracy: 0.9687 - loss: 0.1118 - val_accuracy: 0.8224 - val_loss: 0.9620
# Epoch 28/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 189ms/step - accuracy: 0.9699 - loss: 0.1114 - val_accuracy: 0.8206 - val_loss: 0.9878
# Epoch 29/50
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 175ms/step - accuracy: 0.9738 - loss: 0.0930 - val_accuracy: 0.8201 - val_loss: 1.0190

# %%
# 학습 히스토리의 `loss`, `val_loss`, `accuracy`, `val_accuracy`를 차트로 시각화합니다.

history_dict = history.history

loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)
fig = plt.figure(figsize=(12, 5))

ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, loss, 'b-', label='train_loss')
ax1.plot(epochs, val_loss, 'r-', label='val_loss')
ax1.set_title('Train and Validation Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.grid()
ax1.legend()

accuracy = history_dict['accuracy']
val_accuracy = history_dict['val_accuracy']

ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, accuracy, 'b-', label='train_accuracy')
ax2.plot(epochs, val_accuracy, 'r-', label='val_accuracy')
ax2.set_title('Train and Validation Accuracy')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.grid()
ax2.legend()

plt.show()

# %%
# 문제 2-5: 테스트 데이터셋을 이용해 모델을 평가합니다.
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
# Out:
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8003 - loss: 0.9941
# Test Loss: 1.018081784248352
# Test Accuracy: 0.7943009734153748

# %% [markdown]
# # CIFAR10

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from tensorflow.keras import models, layers
from tensorflow.keras.datasets import cifar10

# %%
# 문제 3-1: cifar10 데이터셋을 로드하고, 훈련 데이터셋에서 20%를 검증 데이터셋으로 분리합니다.
(x_train_full, y_train_full), (x_test, y_test) = cifar10.load_data()

# 정규화 (픽셀 값을 0~1 범위로 스케일링)
x_train_full = x_train_full.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# 훈련 데이터셋을 훈련용 데이터와 검증용 데이터로 나눕니다.
x_train, x_val, y_train, y_val = train_test_split(
    x_train_full, y_train_full, test_size=0.2, random_state=42
)

# 훈련, 검증, 테스트 데이터와 레이블 종류가 몇개인지 출력합니다.
print("전체 학습 데이터: {} 레이블: {}".format(x_train_full.shape, y_train_full.shape))
print("학습 데이터: {} 레이블: {}".format(x_train.shape, y_train.shape))
print("검증 데이터: {} 레이블: {}".format(x_val.shape, y_val.shape))
print("테스트 데이터: {} 레이블: {}".format(x_test.shape, y_test.shape))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 221s 1us/step
# 전체 학습 데이터: (50000, 32, 32, 3) 레이블: (50000, 1)
# 학습 데이터: (40000, 32, 32, 3) 레이블: (40000, 1)
# 검증 데이터: (10000, 32, 32, 3) 레이블: (10000, 1)
# 테스트 데이터: (10000, 32, 32, 3) 레이블: (10000, 1)

# %%
# cifar10의 분류에 해당하는 'airplane', 'automobile', 'bird', 'cat', 'deer', 
# 'dog', 'frog', 'horse', 'ship', 'truck'를 class_name으로 정의합니다.
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# 훈련 데이터의 0번째인 x_train[0]를 이미지로 시각화합니다.


plt.figure()
plt.imshow(x_train[0])
plt.colorbar()
plt.show()

# %%
# 훈련, 검증, 테스트 데이터의 형태(shape)을 출력합니다.
print(x_train.shape)
print(x_val.shape)
print(x_test.shape)
# Out:
# (40000, 32, 32, 3)
# (10000, 32, 32, 3)
# (10000, 32, 32, 3)

# %%
# 문제 3-2: 훈련, 검증, 테스트 데이터의 형태(shape)을 32 * 32 * 3 = 3072로 변형합니다.
x_train = x_train.reshape((x_train.shape[0], -1))
x_val = x_val.reshape((x_val.shape[0], -1))
x_test = x_test.reshape((x_test.shape[0], -1))


print(x_train.shape)
print(x_val.shape)
print(x_test.shape)
# Out:
# (40000, 3072)
# (10000, 3072)
# (10000, 3072)

# %%
# 훈련, 검증, 테스트 데이터를 255로 나누어 0~1 사이의 값으로 변환합니다.
x_train = x_train / 255.
x_val = x_val / 255.
x_test = x_test / 255.

# %%
# 문제 3-3: BatchNormalization과 Dropout을 적용하여 빠른 학습과 과대적합을 방지하고,
# 10개의 이미지를 분류하는 딥러닝 모델을 구성합니다.
model = models.Sequential()
model.add(layers.Dense(512, activation='relu', input_shape=(3072,)))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(10, activation='softmax'))

# %%
model.summary()
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 512)            │     1,573,376 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,710,346 (6.52 MB)
#  Trainable params: 1,708,810 (6.52 MB)
#  Non-trainable params: 1,536 (6.00 KB)

# %%
utils.plot_model(model, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) for `plot_model` to work.

# %%
# 문제 3-4: ModelCheckpoint와 EarlyStopping 콜백 함수를 적용하여 모델 학습을 진행합니다.
checkpoint = callbacks.ModelCheckpoint(
    'best_model_cifar10.keras', save_best_only=True, monitor='val_loss', mode='min'
)
early_stopping = callbacks.EarlyStopping(
    monitor='val_loss', patience=5, restore_best_weights=True
)

history = model.fit(
    x_train, y_train,
    epochs=50,
    batch_size=512,
    validation_data=(x_val, y_val),
    callbacks=[checkpoint, early_stopping]
)
# Out:
# Epoch 1/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 17s 113ms/step - accuracy: 0.2314 - loss: 2.5137 - val_accuracy: 0.1030 - val_loss: 2.3062
# Epoch 2/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 88ms/step - accuracy: 0.3186 - loss: 1.9584 - val_accuracy: 0.1030 - val_loss: 2.3049
# Epoch 3/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 77ms/step - accuracy: 0.3512 - loss: 1.8320 - val_accuracy: 0.1031 - val_loss: 2.2930
# Epoch 4/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.3624 - loss: 1.7828 - val_accuracy: 0.1085 - val_loss: 2.2643
# Epoch 5/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - accuracy: 0.3871 - loss: 1.7378 - val_accuracy: 0.1923 - val_loss: 2.1735
# Epoch 6/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 75ms/step - accuracy: 0.3917 - loss: 1.7077 - val_accuracy: 0.2708 - val_loss: 2.0526
# Epoch 7/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 93ms/step - accuracy: 0.4039 - loss: 1.6773 - val_accuracy: 0.2770 - val_loss: 2.0304
# Epoch 8/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 87ms/step - accuracy: 0.4127 - loss: 1.6592 - val_accuracy: 0.3645 - val_loss: 1.7876
# Epoch 9/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.4186 - loss: 1.6501 - val_accuracy: 0.4163 - val_loss: 1.6587
# Epoch 10/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - accuracy: 0.4233 - loss: 1.6271 - val_accuracy: 0.4365 - val_loss: 1.5859
# Epoch 11/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 78ms/step - accuracy: 0.4204 - loss: 1.6295 - val_accuracy: 0.4197 - val_loss: 1.6391
# Epoch 12/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 78ms/step - accuracy: 0.4217 - loss: 1.6263 - val_accuracy: 0.4321 - val_loss: 1.5823
# Epoch 13/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 87ms/step - accuracy: 0.4344 - loss: 1.6066 - val_accuracy: 0.4489 - val_loss: 1.5486
# Epoch 14/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 74ms/step - accuracy: 0.4343 - loss: 1.6006 - val_accuracy: 0.4448 - val_loss: 1.5591
# Epoch 15/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - accuracy: 0.4349 - loss: 1.5886 - val_accuracy: 0.4409 - val_loss: 1.5667
# Epoch 16/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 66ms/step - accuracy: 0.4342 - loss: 1.5920 - val_accuracy: 0.4223 - val_loss: 1.5998
# Epoch 17/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 87ms/step - accuracy: 0.4435 - loss: 1.5658 - val_accuracy: 0.4555 - val_loss: 1.5164
# Epoch 18/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 85ms/step - accuracy: 0.4392 - loss: 1.5804 - val_accuracy: 0.4453 - val_loss: 1.5484
# Epoch 19/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - accuracy: 0.4423 - loss: 1.5758 - val_accuracy: 0.4438 - val_loss: 1.5742
# Epoch 20/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 0.4427 - loss: 1.5603 - val_accuracy: 0.4645 - val_loss: 1.5115
# Epoch 21/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 83ms/step - accuracy: 0.4445 - loss: 1.5557 - val_accuracy: 0.4310 - val_loss: 1.5534
# Epoch 22/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 9s 107ms/step - accuracy: 0.4539 - loss: 1.5376 - val_accuracy: 0.4600 - val_loss: 1.5029
# Epoch 23/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 9s 109ms/step - accuracy: 0.4503 - loss: 1.5467 - val_accuracy: 0.4566 - val_loss: 1.5002
# Epoch 24/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 83ms/step - accuracy: 0.4536 - loss: 1.5407 - val_accuracy: 0.4687 - val_loss: 1.4844
# Epoch 25/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - accuracy: 0.4490 - loss: 1.5489 - val_accuracy: 0.4320 - val_loss: 1.5845
# Epoch 26/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 69ms/step - accuracy: 0.4523 - loss: 1.5361 - val_accuracy: 0.4647 - val_loss: 1.4990
# Epoch 27/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - accuracy: 0.4580 - loss: 1.5303 - val_accuracy: 0.4520 - val_loss: 1.5069
# Epoch 28/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.4587 - loss: 1.5193 - val_accuracy: 0.4619 - val_loss: 1.5071
# Epoch 29/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - accuracy: 0.4605 - loss: 1.5228 - val_accuracy: 0.4757 - val_loss: 1.4692
# Epoch 30/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - accuracy: 0.4653 - loss: 1.5073 - val_accuracy: 0.4578 - val_loss: 1.5192
# Epoch 31/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - accuracy: 0.4582 - loss: 1.5150 - val_accuracy: 0.4645 - val_loss: 1.5004
# Epoch 32/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 77ms/step - accuracy: 0.4630 - loss: 1.5167 - val_accuracy: 0.4681 - val_loss: 1.4777
# Epoch 33/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 7s 85ms/step - accuracy: 0.4647 - loss: 1.5119 - val_accuracy: 0.4553 - val_loss: 1.5092
# Epoch 34/50
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 6s 75ms/step - accuracy: 0.4596 - loss: 1.5157 - val_accuracy: 0.4709 - val_loss: 1.4703

# %%
# 문제 3-5: 학습 히스토리의 `loss`, `val_loss`, `accuracy`, `val_accuracy`를 차트로 시각화합니다.

history_dict = history.history

loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(loss) + 1)
fig = plt.figure(figsize=(12, 5))

ax1 = fig.add_subplot(1, 2, 1)
ax1.plot(epochs, loss, 'b-', label='train_loss')
ax1.plot(epochs, val_loss, 'r-', label='val_loss')
ax1.set_title('Train and Validation Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.grid()
ax1.legend()

accuracy = history_dict['accuracy']
val_accuracy = history_dict['val_accuracy']

ax2 = fig.add_subplot(1, 2, 2)
ax2.plot(epochs, accuracy, 'b-', label='train_accuracy')
ax2.plot(epochs, val_accuracy, 'r-', label='val_accuracy')
ax2.set_title('Train and Validation Accuracy')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.grid()
ax2.legend()

plt.show()

# %%
# 테스트 데이터셋을 이용해 모델을 평가합니다.
model.evaluate(x_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.4797 - loss: 1.4629
# [1.4683618545532227, 0.4778999984264374]
